# %% [markdown]
# # Redrob Candidate Discovery & Ranking AI Sandbox
#
# Welcome to the sandbox for the **Senior AI Engineer - Founding Team** candidate ranker, designed by Team **Antigravity**.
#
# This notebook replicates the staging environment, downloads the repository, runs the ranker on sample profiles, and prints the top matches.

# %%
# 1. Clone the repository (Replace USERNAME with your actual GitHub username)
# !git clone https://github.com/YOUR_USERNAME/RedrobHackathon.git
# %cd RedrobHackathon

# %%
# 2. Install ReportLab (required for slide deck compilation)
# !pip install reportlab

# %%
# 3. Run the ranker on the sample candidates JSON included in the bundle
# !python rank.py --candidates "./[PUB] India_runs_data_and_ai_challenge/[PUB] India_runs_data_and_ai_challenge/India_runs_data_and_ai_challenge/sample_candidates.json" --out "./sample_output.csv"

# %%
# 4. Display the top candidates
import pandas as pd
df = pd.read_csv("sample_output.csv")
df.head(10)
